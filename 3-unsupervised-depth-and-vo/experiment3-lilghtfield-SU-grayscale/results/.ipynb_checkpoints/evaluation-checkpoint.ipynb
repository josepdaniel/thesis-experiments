# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_sequence(sequence):

    pose_predictions = np.load(f"./{sequence}/poses.npy")
    actual_poses = np.load(f"/home/joseph/Documents/epidata/module-1-1/{sequence}/poses_gt_relative.npy")
    actual_poses_absolute = np.load(f"/home/joseph/Documents/epidata/module-1-1/{sequence}/poses_gt_absolute.npy")
    print(pose_predictions.shape)
    print(actual_poses.shape)

    xs_pred = -1*np.cumsum(pose_predictions[:, 0]) * 8
    ys_pred = np.cumsum(pose_predictions[:, 1]) * 4
    zs_pred = np.cumsum(pose_predictions[:, 2]) * 4

    xs_actual = np.cumsum(actual_poses[:, 0])
    ys_actual = np.cumsum(actual_poses[:, 1])
    zs_actual = np.cumsum(actual_poses[:, 2])


    xs_actual_absolute = np.cumsum(actual_poses_absolute[:, 0])
    ys_actual_absolute = np.cumsum(actual_poses_absolute[:, 1])
    zs_actual_absolute = np.cumsum(actual_poses_absolute[:, 2])

    # %matplotlib inline

    fig = plt.figure(figsize = (15,5))
    ax1 = fig.add_subplot(121)
    ax1.plot(xs_pred, zs_pred*-1)
    ax1.plot(xs_actual, zs_actual, c='r')
    ax1.set_title("Predicted vs Actual Trajectory (XZ plane)")
    ax1.axis('equal')

    
    ax2 = fig.add_subplot(122)
    ax2.plot(xs_pred, ys_pred)
    ax2.plot(xs_actual, ys_actual, c='r')
    ax2.set_title("Ground Truth Trajectory (XY plane)")
    ax2.axis('equal')

    



    fig.suptitle(f'{sequence}', fontsize=16)

# %%
plot_sequence("seq2")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-660c46b3234c> in <module>
# ----> 1 plot_sequence("seq2")
#
# <ipython-input-2-cf1a4bab8bdd> in plot_sequence(sequence)
#       1 def plot_sequence(sequence):
#       2
# ----> 3     pose_predictions = np.load(f"./{sequence}/poses.npy")
#       4     actual_poses = np.load(f"/home/joseph/Documents/epidata/module-1-1/{sequence}/poses_gt_relative.npy")
#       5     actual_poses_absolute = np.load(f"/home/joseph/Documents/epidata/module-1-1/{sequence}/poses_gt_absolute.npy")
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     426         own_fid = False
#     427     else:
# --> 428         fid = open(os_fspath(file), "rb")
#     429         own_fid = True
#     430
#
# FileNotFoundError: [Errno 2] No such file or directory: './seq2/poses.npy'

# %%
plot_sequence("seq3")

# %%
plot_sequence("seq4")

# %%
plot_sequence("seq5")

# %%
plot_sequence("seq6")

# %%
plot_sequence("seq7")

# %%
plot_sequence("seq8")

# %%
plot_sequence("seq9")

# %%
plot_sequence("seq10")

# %%
plot_sequence("seq11")

# %%
plot_sequence("seq13")

# %%
plot_sequence("seq14")
# Out:
# (165, 6)
# (166, 6)
